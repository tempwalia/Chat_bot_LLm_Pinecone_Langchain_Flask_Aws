# %%
# %pwd
# Out:
# 'c:\\Users\\DELL\\Desktop\\ChatBot\\Chat_bot_LLm_Pinecone_Langchain_Flask_Aws'

# %%
import os
os.chdir("../")

# %%
from langchain_community.document_loaders import PyPDFLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from langchain.document_loaders import PyPDFLoader,DerectoryLoader
#       3 from langchain.text_splitter import RecursiveCharacterTextSpliter
#
# ImportError: cannot import name 'DerectoryLoader' from 'langchain.document_loaders' (c:\Users\DELL\Desktop\ChatBot\Chat_bot_LLm_Pinecone_Langchain_Flask_Aws\chatbot\Lib\site-packages\langchain\document_loaders\__init__.py)
